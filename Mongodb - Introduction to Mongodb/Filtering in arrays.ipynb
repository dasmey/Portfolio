# %%
# all movies including korean and english + all others
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

# Replace XXXX with your connection URI from the Atlas UI
client = MongoClient("mongodb://Davy:sonus1305@clusterdavy-shard-00-00-ljkfh.mongodb.net:27017,clusterdavy-shard-00-01-ljkfh.mongodb.net:27017,clusterdavy-shard-00-02-ljkfh.mongodb.net:27017/test?ssl=true&replicaSet=ClusterDavy-shard-0&authSource=admin&retryWrites=true")

filter = {
    'languages': {'$all': ['Korean', 'English']}
}

clear_output()
pprint.pprint(list(client.ClusterDavy.movies.find(filter)))
# Out:
# [{'_id': ObjectId('5b97f3210812b871018ac0b5'),
#   'cast': ['Rock Hudson', 'Anna Kashfi', 'Dan Duryea', 'Don DeFore'],
#   'countries': ['USA'],
#   'directors': ['Douglas Sirk'],
#   'fullPlot': 'Dean Hess, who entered the ministry to atone for bombing a '
#               "German orphanage, decides he's a failure at preaching. Rejoined "
#               'to train pilots early in the Korean War, he finds Korean '
#               'orphans raiding the airbase garbage. With a pretty Korean '
#               'teacher, he sets up an orphanage for them and others. But he '
#               'finds that to protect his charges, he has to kill.',
#   'genres': ['Biography', 'Drama', 'History'],
#   'imdb': {'id': 50171, 'rating': 6.3, 'votes': 654},
#   'languages': ['English', 'Korean'],
#   'lastupdated': '2015-09-02 00:25:52.287000000',
#   'plot': 'A remorseful bomber pilot-turned-minister rejoins for the Korean '
#           'War.',
# ...

# %%
# all movies with Korean first and English in second languages
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

# Replace XXXX with your connection URI from the Atlas UI
client = MongoClient("mongodb://Davy:sonus1305@clusterdavy-shard-00-00-ljkfh.mongodb.net:27017,clusterdavy-shard-00-01-ljkfh.mongodb.net:27017,clusterdavy-shard-00-02-ljkfh.mongodb.net:27017/test?ssl=true&replicaSet=ClusterDavy-shard-0&authSource=admin&retryWrites=true")

filter = {
    'languages': ['Korean', 'English']
}

clear_output()
pprint.pprint(list(client.ClusterDavy.movies.find(filter)))
# Out:
# [{'_id': ObjectId('5b97f3250812b871018b0a6a'),
#   'awards': '1 win.',
#   'cast': ['Jock Mahoney', 'Pat Yi', 'Youngson Chon', 'Dong-hwi Jang'],
#   'countries': ['South Korea', 'USA'],
#   'directors': ['Man-hui Lee'],
#   'fullPlot': 'A division of marines survive a battle with the Chinese army '
#               'but find themselves stranded without contact on the wrong side '
#               'of the front.',
#   'genres': ['Drama', 'War'],
#   'imdb': {'id': 239594, 'rating': 6.9, 'votes': 60},
#   'languages': ['Korean', 'English'],
#   'lastupdated': '2015-08-17 00:00:04.390000000',
#   'plot': 'A division of marines survive a battle with the Chinese army but '
#           'find themselves stranded without contact on the wrong side of the '
#           'front.',
#   'released': datetime.datetime(1966, 2, 1, 0, 0),
#   'runtime': 88,
#   'title': 'Marine Battleground',
#   'type': 'movie',
#   'writers': ['Kook-jin Jang (story)', 'Milton Mann', 'Han-chul Yu'],
#   'year': 1963},
# ...

# %%
# all movies with Korean in first position
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

# Replace XXXX with your connection URI from the Atlas UI
client = MongoClient("mongodb://Davy:sonus1305@clusterdavy-shard-00-00-ljkfh.mongodb.net:27017,clusterdavy-shard-00-01-ljkfh.mongodb.net:27017,clusterdavy-shard-00-02-ljkfh.mongodb.net:27017/test?ssl=true&replicaSet=ClusterDavy-shard-0&authSource=admin&retryWrites=true")

filter = {
    'languages.0': 'Korean'
}

clear_output()
pprint.pprint(list(client.ClusterDavy.movies.find(filter)))
# Out:
# [{'_id': ObjectId('5b97f3220812b871018aca11'),
#   'cast': ['Yeong-il Oh', 'Jeong-im Nam', 'Sun-jae Lee', 'Moon Kang'],
#   'countries': ['South Korea', 'Japan'],
#   'directors': ['Ki-duk Kim'],
#   'fullPlot': 'Earthquakes in central Korea turn out to be the work of '
#               'Yongary, a prehistoric gasoline-eating reptile that soon goes '
#               'on a rampage through Seoul.',
#   'genres': ['Sci-Fi', 'Horror'],
#   'imdb': {'id': 61549, 'rating': 4.3, 'votes': 612},
#   'languages': ['Korean'],
#   'lastupdated': '2015-07-17 02:27:45.660000000',
#   'plot': 'Earthquakes in central Korea turn out to be the work of Yongary, a '
#           'prehistoric gasoline-eating reptile that soon goes on a rampage '
#           'through Seoul.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTUxNDQ4MjY3M15BMl5BanBnXkFtZTcwMjkyMDQ1MQ@@._V1_SX300.jpg',
#   'rated': 'PG',
#   'released': datetime.datetime(1967, 8, 13, 0, 0),
#   'runtime': 80,
# ...

# %%
# all movies with Korean in first position but returning only title and languages (_id must explicitly be excluded)
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

# Replace XXXX with your connection URI from the Atlas UI
client = MongoClient("mongodb://Davy:sonus1305@clusterdavy-shard-00-00-ljkfh.mongodb.net:27017,clusterdavy-shard-00-01-ljkfh.mongodb.net:27017,clusterdavy-shard-00-02-ljkfh.mongodb.net:27017/test?ssl=true&replicaSet=ClusterDavy-shard-0&authSource=admin&retryWrites=true")

filter = {
    'languages.0': 'Korean'
}

projection = {
    '_id' : 0,
    'title' : 1,
    'languages' : 1
}

clear_output()
pprint.pprint(list(client.ClusterDavy.movies.find(filter, projection)))
# Out:
# [{'languages': ['Korean'], 'title': 'Yongary, Monster from the Deep'},
#  {'languages': ['Korean'], 'title': 'Bulgasari'},
#  {'languages': ['Korean'], 'title': 'The Surrogate Woman'},
#  {'languages': ['Korean'],
#   'title': 'Why Has Bodhi-Dharma Left for the East?: A Zen Fable'},
#  {'languages': ['Korean'], 'title': 'Sopyonje'},
#  {'languages': ['Korean'], 'title': '301/302'},
#  {'languages': ['Korean', 'Cantonese'], 'title': 'Beyond Hypothermia'},
#  {'languages': ['Korean'], 'title': 'The Day a Pig Fell Into the Well'},
#  {'languages': ['Korean'], 'title': 'Green Fish'},
#  {'languages': ['Korean'], 'title': 'Motel Cactus'},
#  {'languages': ['Korean'], 'title': 'Christmas in August'},
#  {'languages': ['Korean'], 'title': 'The Housemaid'},
#  {'languages': ['Korean'], 'title': 'Io Island'},
#  {'languages': ['Korean'], 'title': 'Christmas in August'},
#  {'languages': ['Korean'], 'title': 'The Power of Kangwon Province'},
#  {'languages': ['Korean'], 'title': 'Biteu'},
# ...
